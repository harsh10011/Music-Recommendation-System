# %% [markdown]
# # Spotify Music Recommendation App

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px 

import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
#  16  release_date      170653 non-null  object
#  17  speechiness       170653 non-null  float64
#  18  tempo             170653 non-null  float64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.7+ MB

# %%
data.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# 25%    1.698270e+05       0.255000       0.000000          0.000000
# 50%    2.074670e+05       0.471000       0.000000          0.000216
# 75%    2.624000e+05       0.703000       0.000000          0.102000
# max    5.403500e+06       1.000000       1.000000          1.000000
#
#                  key       liveness       loudness           mode  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        5.199844       0.205839     -11.467990       0.706902
# std         3.515094       0.174805       5.697943       0.455184
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         2.000000       0.098800     -14.615000       0.000000
# 50%         5.000000       0.136000     -10.580000       1.000000
# 75%         8.000000       0.261000      -7.183000       1.000000
# max        11.000000       1.000000       3.855000       1.000000
#
#           popularity    speechiness          tempo
# count  170653.000000  170653.000000  170653.000000
# mean       31.431794       0.098393     116.861590
# std        21.826615       0.162740      30.708533
# min         0.000000       0.000000       0.000000
# 25%        11.000000       0.034900      93.421000
# 50%        33.000000       0.045000     114.729000
# 75%        48.000000       0.075600     135.537000
# max       100.000000       0.970000     243.507000

# %%
data.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='object')

# %%
data = data.reindex(columns =  ['name', 'year', 'artists', 'duration_ms', 'popularity', 'valence', 'acousticness',  'danceability',
       'energy', 'explicit', 'id', 'instrumentalness', 'key',
       'liveness', 'loudness', 'mode',  'release_date',
       'speechiness', 'tempo'])

# %%
data.head()
# Out:
#                                                 name  year  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...  1921
# 1                            Clancy Lowered the Boom  1921
# 2                                          Gati Bali  1921
# 3                                          Danny Boy  1921
# 4                        When Irish Eyes Are Smiling  1921
#
#                                              artists  duration_ms  popularity  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...       831667           4
# 1                                     ['Dennis Day']       180533           5
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...       500062           5
# 3                                   ['Frank Parker']       210000           3
# 4                                     ['Phil Regan']       166693           2
#
#    valence  acousticness  danceability  energy  explicit  \
# 0   0.0594         0.982         0.279   0.211         0
# 1   0.9630         0.732         0.819   0.341         0
# 2   0.0394         0.961         0.328   0.166         0
# 3   0.1650         0.967         0.275   0.309         0
# 4   0.2530         0.957         0.418   0.193         0
#
#                        id  instrumentalness  key  liveness  loudness  mode  \
# 0  4BJqT0PrAfrxzMOxytFOIz          0.878000   10     0.665   -20.096     1
# 1  7xPhfUan2yNtyFG0cUWkt8          0.000000    7     0.160   -12.441     1
# 2  1o6I8BglA6ylDMrIELygv1          0.913000    3     0.101   -14.850     1
# 3  3ftBPsC5vPBKxYSee08FDH          0.000028    5     0.381    -9.316     1
# 4  4d6HGyGT8e121BsdKmw9v6          0.000002    3     0.229   -10.096     1
#
#   release_date  speechiness    tempo
# 0         1921       0.0366   80.954
# 1         1921       0.4150   60.936
# 2         1921       0.0339  110.339
# 3         1921       0.0354  100.109
# 4         1921       0.0380  101.665

# %%
data = data.drop(['release_date','id','key','mode','explicit'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              170653 non-null  object
#  1   year              170653 non-null  int64
#  2   artists           170653 non-null  object
#  3   duration_ms       170653 non-null  int64
#  4   popularity        170653 non-null  int64
#  5   valence           170653 non-null  float64
#  6   acousticness      170653 non-null  float64
#  7   danceability      170653 non-null  float64
#  8   energy            170653 non-null  float64
#  9   instrumentalness  170653 non-null  float64
#  10  liveness          170653 non-null  float64
#  11  loudness          170653 non-null  float64
#  12  speechiness       170653 non-null  float64
#  13  tempo             170653 non-null  float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 18.2+ MB

# %%
data.head(5)
# Out:
#                                                 name  year  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...  1921
# 1                            Clancy Lowered the Boom  1921
# 2                                          Gati Bali  1921
# 3                                          Danny Boy  1921
# 4                        When Irish Eyes Are Smiling  1921
#
#                                              artists  duration_ms  popularity  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...       831667           4
# 1                                     ['Dennis Day']       180533           5
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...       500062           5
# 3                                   ['Frank Parker']       210000           3
# 4                                     ['Phil Regan']       166693           2
#
#    valence  acousticness  danceability  energy  instrumentalness  liveness  \
# 0   0.0594         0.982         0.279   0.211          0.878000     0.665
# 1   0.9630         0.732         0.819   0.341          0.000000     0.160
# 2   0.0394         0.961         0.328   0.166          0.913000     0.101
# 3   0.1650         0.967         0.275   0.309          0.000028     0.381
# 4   0.2530         0.957         0.418   0.193          0.000002     0.229
#
#    loudness  speechiness    tempo
# 0   -20.096       0.0366   80.954
# 1   -12.441       0.4150   60.936
# 2   -14.850       0.0339  110.339
# 3    -9.316       0.0354  100.109
# 4   -10.096       0.0380  101.665

# %%
# Converting music duration from milliseconds to minutes

data['duration_ms'] = (data['duration_ms']/(1000*60))%60

# %%
data.head()
# Out:
#                                                 name  year  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...  1921
# 1                            Clancy Lowered the Boom  1921
# 2                                          Gati Bali  1921
# 3                                          Danny Boy  1921
# 4                        When Irish Eyes Are Smiling  1921
#
#                                              artists  duration_ms  popularity  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...    13.861117           4
# 1                                     ['Dennis Day']     3.008883           5
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...     8.334367           5
# 3                                   ['Frank Parker']     3.500000           3
# 4                                     ['Phil Regan']     2.778217           2
#
#    valence  acousticness  danceability  energy  instrumentalness  liveness  \
# 0   0.0594         0.982         0.279   0.211          0.878000     0.665
# 1   0.9630         0.732         0.819   0.341          0.000000     0.160
# 2   0.0394         0.961         0.328   0.166          0.913000     0.101
# 3   0.1650         0.967         0.275   0.309          0.000028     0.381
# 4   0.2530         0.957         0.418   0.193          0.000002     0.229
#
#    loudness  speechiness    tempo
# 0   -20.096       0.0366   80.954
# 1   -12.441       0.4150   60.936
# 2   -14.850       0.0339  110.339
# 3    -9.316       0.0354  100.109
# 4   -10.096       0.0380  101.665

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              170653 non-null  object
#  1   year              170653 non-null  int64
#  2   artists           170653 non-null  object
#  3   duration_ms       170653 non-null  float64
#  4   popularity        170653 non-null  int64
#  5   valence           170653 non-null  float64
#  6   acousticness      170653 non-null  float64
#  7   danceability      170653 non-null  float64
#  8   energy            170653 non-null  float64
#  9   instrumentalness  170653 non-null  float64
#  10  liveness          170653 non-null  float64
#  11  loudness          170653 non-null  float64
#  12  speechiness       170653 non-null  float64
#  13  tempo             170653 non-null  float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 18.2+ MB

# %%
def get_decade(year):
    period_start = int(year/10) * 10
    decade = '{}'.format(period_start)
    return decade

decade = data['year'].apply(get_decade)

# %%
decade.value_counts()
# Out:
# 1970    20000
# 1990    19901
# 1950    19850
# 1980    19850
# 2010    19774
# 2000    19646
# 1960    19549
# 1940    15378
# 1930     9549
# 1920     5126
# 2020     2030
# Name: year, dtype: int64

# %%
data.shape
# Out:
# (170653, 14)

# %%
# Dropping data from the year 1920 to 1949 as it might skew the results

data.drop(data[data.year <= 1949].index, inplace=True)

# %%
data.shape
# Out:
# (140600, 14)

# %%
def get_decade(year):
    period_start = int(year/10) * 10
    decade = '{}'.format(period_start)
    return decade

decade = data['year'].apply(get_decade)
decade.value_counts()
# Out:
# 1970    20000
# 1990    19901
# 1950    19850
# 1980    19850
# 2010    19774
# 2000    19646
# 1960    19549
# 2020     2030
# Name: year, dtype: int64

# %%
data.head(5)
# Out:
#                                                    name  year  \
# 5606                           Someone To Watch Over Me  1950
# 5607                            I've Got A Crush On You  1950
# 5608                                           Stardust  1950
# 5609          If You've Got the Money I've Got the Time  1950
# 5610  Powder Your Face With Sunshine (Smile! Smile! ...  1950
#
#                                                artists  duration_ms  \
# 5606                               ['Ella Fitzgerald']     3.277783
# 5607                               ['Ella Fitzgerald']     3.274000
# 5608                              ['Hoagy Carmichael']     2.439117
# 5609                                ['Lefty Frizzell']     2.988450
# 5610  ['Dean Martin', 'Paul Weston And His Orchestra']     2.585117
#
#       popularity  valence  acousticness  danceability  energy  \
# 5606          56    0.197         0.990         0.354  0.0851
# 5607          55    0.258         0.986         0.455  0.1060
# 5608          42    0.345         0.960         0.658  0.0542
# 5609          43    0.951         0.830         0.545  0.3920
# 5610          37    0.540         0.958         0.498  0.2210
#
#       instrumentalness  liveness  loudness  speechiness    tempo
# 5606          0.000004    0.1230   -13.738       0.0345   97.684
# 5607          0.000000    0.1220   -14.086       0.0422   66.807
# 5608          0.106000    0.1060   -19.427       0.0596   90.138
# 5609          0.000094    0.0903   -10.091       0.0481  208.426
# 5610          0.053000    0.2220   -11.750       0.0450  168.748

# %%
sns.countplot(data=data, x='popularity').set(xticklabels=[])
plt.title("Song popularity countplot between 0 to 100")
plt.show()

# %%
corr = data.corr()
plt.figure(figsize=(10,4))
sns.heatmap(corr,annot=True,cmap='Blues')
# Out:
# C:\Users\Roshan\AppData\Local\Temp\ipykernel_38416\3887510620.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <AxesSubplot: >

# %%
# Dropping duration, speechiness and tempo columns from the dataset as they have almost no-correlation with other variables

data = data.drop(['duration_ms', 'speechiness', 'tempo'], axis=1)

# %%
corr = data.corr()
plt.figure(figsize=(10,4))
sns.heatmap(corr,annot=True,cmap='Blues')
# Out:
# C:\Users\Roshan\AppData\Local\Temp\ipykernel_38416\3887510620.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <AxesSubplot: >

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 10))

fig.suptitle('Understanding the spread of the data')

sns.boxplot(ax=axes[0, 0], data=data, x='valence')
sns.boxplot(ax=axes[0, 1], data=data, x='acousticness')
sns.boxplot(ax=axes[0, 2], data=data, x='danceability')
sns.boxplot(ax=axes[1, 0], data=data, x='energy')
sns.boxplot(ax=axes[1, 1], data=data, x='instrumentalness')
sns.boxplot(ax=axes[1, 2], data=data, x='liveness')
sns.boxplot(ax=axes[2, 0], data=data, x='loudness')
# Out:
# <AxesSubplot: xlabel='loudness'>

# %%
data.columns
# Out:
# Index(['name', 'year', 'artists', 'popularity', 'valence', 'acousticness',
#        'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140600 entries, 5606 to 170652
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              140600 non-null  object
#  1   year              140600 non-null  int64
#  2   artists           140600 non-null  object
#  3   popularity        140600 non-null  int64
#  4   valence           140600 non-null  float64
#  5   acousticness      140600 non-null  float64
#  6   danceability      140600 non-null  float64
#  7   energy            140600 non-null  float64
#  8   instrumentalness  140600 non-null  float64
#  9   liveness          140600 non-null  float64
#  10  loudness          140600 non-null  float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 12.9+ MB

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 10))

fig.suptitle('Understanding the distribution of all the data')
sns.distplot(data['valence'],kde = True, ax=axes[0, 0])
sns.distplot(data['acousticness'],kde = True, ax=axes[0, 1])
sns.distplot(data['danceability'],kde = True, ax=axes[0, 2])
sns.distplot(data['energy'],kde = True, ax=axes[1, 0])
sns.distplot(data['instrumentalness'],kde = True, ax=axes[1, 1])
sns.distplot(data['liveness'],kde = True, ax=axes[1, 2])
sns.distplot(data['loudness'],kde = True, ax=axes[2, 0])
# Out:
# <AxesSubplot: xlabel='loudness', ylabel='Density'>

# %% [markdown]
# <p><b>Valence</b>: The data is not skewed but the normal distribution looks more like a uniform distribution</p>

# %%
scaler = MinMaxScaler()
cols = ['acousticness','liveness','loudness','instrumentalness']
data[cols] = scaler.fit_transform(data[cols])

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 10))

fig.suptitle('Understanding the distribution of all the data')
sns.distplot(data['valence'],kde = True, ax=axes[0, 0])
sns.distplot(data['acousticness'],kde = True, ax=axes[0, 1])
sns.distplot(data['danceability'],kde = True, ax=axes[0, 2])
sns.distplot(data['energy'],kde = True, ax=axes[1, 0])
sns.distplot(data['instrumentalness'],kde = True, ax=axes[1, 1])
sns.distplot(data['liveness'],kde = True, ax=axes[1, 2])
sns.distplot(data['loudness'],kde = True, ax=axes[2, 0])
# Out:
# <AxesSubplot: xlabel='loudness', ylabel='Density'>

# %%
Test to check commits
